# %% [markdown]
# # Quickstart Guide for Strands Agents
#
# Strands Agents is a powerful framework for building AI agents that can interact with AWS services and perform complex tasks. This quickstart guide will help you get started with creating your first Strands agent.
#
# ## Prerequisites
#
# - Python 3.10 or later
# - AWS account configured with appropriate permissions
# - Basic understanding of Python programming
#
# Lets get started !

# %%
# Install Strands using pip

# !pip install strands-agents strands-agents-tools
# Out:
# Requirement already satisfied: strands-agents in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (1.40.0)
# Requirement already satisfied: strands-agents-tools in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (0.5.3)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents) (1.43.12)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents) (1.43.12)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents) (0.18.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents) (4.26.0)
# Requirement already satisfied: mcp<2.0.0,>=1.23.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents) (1.27.1)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents) (1.42.1)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents) (0.63b1)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents) (1.42.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents) (6.0.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents) (6.0.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools) (3.13.5)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools) (0.4.1)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools) (1.2.2)
# Requirement already satisfied: pillow<13.0.0,>=12.1.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools) (12.2.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools) (3.0.52)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools) (2.12.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools) (2.32.3)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools) (14.3.4)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools) (1.28.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools) (9.1.4)
# Requirement already satisfied: tzdata in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools) (2025.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools) (1.24.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from boto3<2.0.0,>=1.26.0->strands-agents) (1.1.0)
# Requirement already satisfied: s3transfer<0.18.0,>=0.17.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from boto3<2.0.0,>=1.26.0->strands-agents) (0.17.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from botocore<2.0.0,>=1.29.0->strands-agents) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from botocore<2.0.0,>=1.29.0->strands-agents) (2.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents) (0.30.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools) (4.14.3)
# Requirement already satisfied: six<2,>=1.15 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools) (1.17.0)
# Requirement already satisfied: anyio>=4.5 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (4.8.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (0.4.3)
# Requirement already satisfied: httpx<1.0.0,>=0.27.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (0.28.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (2.14.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (3.4.4)
# Requirement already satisfied: starlette>=0.27 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.63b1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (0.63b1)
# Requirement already satisfied: wrapt<3.0.0,>=1.0.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (2.2.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-instrumentation==0.63b1->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (0.63b1)
# Requirement already satisfied: packaging>=18.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-instrumentation==0.63b1->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents) (24.2)
# Requirement already satisfied: wcwidth in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools) (0.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents) (2.46.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools) (2.19.1)
# Requirement already satisfied: slack_sdk<4,>=3.38.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools) (3.42.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio>=4.5->mcp<2.0.0,>=1.23.0->strands-agents) (1.3.1)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools) (2.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1.0.0,>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents) (0.14.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.23.0->strands-agents) (1.2.2)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents) (48.0.0)
# Requirement already satisfied: click>=7.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn>=0.31.1->mcp<2.0.0,>=1.23.0->strands-agents) (8.1.8)
# Requirement already satisfied: colorama in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click>=7.0->uvicorn>=0.31.1->mcp<2.0.0,>=1.23.0->strands-agents) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents) (3.0)
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\batto\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Creating Your First Agent
#
# Lets get an overview of the agentic components needed.
#
# ### 1. Create a simple Agent:
#
# This will create an agent with the default model provider, [Amazon Bedrock](https://aws.amazon.com/bedrock/), and the default model, Claude Sonnet 4, in the region of your AWS setup. While the agent runs in the same local environment as it is being invoked, Amazon Bedrock models will run in an AWS account and your agent will invoke the model in the cloud account. The architecture looks as following:
#
# <div style="text-align:center">
#     <img src="images/simple_agent.png" width="75%" />
# </div>

# %%
import warnings
warnings.filterwarnings(action="ignore", message=r"datetime.datetime.utcnow") 

from strands import Agent
# Initialize your agent
agent = Agent(
    model="us.anthropic.claude-sonnet-4-5-20250929-v1:0",  # Optional: Specify the model ID
    system_prompt="You are a helpful assistant that provides concise responses."
)

# Send a message to the agent
response = agent("Hello! Tell me a joke.")
# Out:
# Hello! Here's a joke for you:
#
# Why don't scientists trust atoms?
#
# Because they make up everything! 😄

# %% [markdown]
# ### 2. Add Tools to the Agent:
#
# The [strands-agents-tools](https://github.com/strands-agents/tools) repository provides some in-built tools which you can import. You can also create custom tools using the `@tool` decorator. We can create agents with built-in and custom tools. For instance, adding the built-in tool of a calculator and a custom tool for getting the weather you get the following architecture:
# <div style="text-align:center">
#     <img src="images/agent_with_tools.png" width="75%" />
# </div>
#
# Implementing this architecture you have the following:

# %%
from strands import Agent, tool
from strands_tools import calculator # Import the calculator tool

# Create a custom tool 
@tool
def weather():
    """ Get weather """ # Dummy implementation
    return "sunny"

agent = Agent(
    model="us.anthropic.claude-sonnet-4-5-20250929-v1:0",  # Optional: Specify the model ID
    tools=[calculator, weather],
    system_prompt="You're a helpful assistant. You can do simple math calculation, and tell the weather.")

response = agent("What is the weather today?")
print(response)
# Out:
# Tool #1: weather
# The weather today is **sunny**! ☀️ It's a beautiful day outside.The weather today is **sunny**! ☀️ It's a beautiful day outside.

# %% [markdown]
# ### Invoking tool directly
#
# For some applications it is important to directly call the tool. For instance, you might want to debug the tool, pre-populate the agent knowledge with your customer's information or using a tool inside of another tool. In Strands you can do it using the ``tool`` method of your agent followed by the tool name

# %%
# Alternatively, you can invoke the tool directly like so:
agent.tool.calculator(expression="sin(x)", mode="derive", wrt="x", order=2)

# %% [markdown]
# ### 3. Changing the log level and format:
#
# Strands SDK uses Python's standard `logging` module to provide visibility into its operations.
#
# The Strands Agents SDK implements a straightforward logging approach:
#
# 1. **Module-level Loggers**: Each module in the SDK creates its own logger using logging.getLogger(__name__), following Python best practices for hierarchical logging.
# 2. **Root Logger**: All loggers in the SDK are children of the "strands" root logger, making it easy to configure logging for the entire SDK.
# 3. **Default Behavior**: By default, the SDK doesn't configure any handlers or log levels, allowing you to integrate it with your application's logging configuration.
#
# To enable logging for the Strands Agents SDK, you can configure the **"strands"** logger. If you want to change the log level, for example during debugging, or modify the log format, you can set the logger configuration as follows:

# %%
import logging
from strands import Agent

# Enables Strands debug log level
logging.getLogger("strands").setLevel(logging.DEBUG) # or logging.INFO

# Sets the logging format and streams logs to stderr
logging.basicConfig(
    format="%(levelname)s | %(name)s | %(message)s",
    handlers=[logging.StreamHandler()]
)

agent = Agent(model="us.anthropic.claude-sonnet-4-5-20250929-v1:0")  # Optional: Specify the model ID
agent("Hello!")

# %% [markdown]
# ### 4. Model Provider
#
# The default model provider is [Amazon Bedrock](https://aws.amazon.com/bedrock/) and the default model is Claude Sonnet 4 in the region of your current AWS environment
#
# You can specify a different model in Amazon Bedrock providing the model ID string directly:

# %%
from strands import Agent

agent = Agent(model="us.anthropic.claude-haiku-4-5-20251001-v1:0")
print(agent.model.config)

# %% [markdown]
# For more control over the model configuration, you can create a `BedrockModel` provider instance:

# %%
import boto3
from strands import Agent
from strands.models import BedrockModel

# Create a BedrockModel
bedrock_model = BedrockModel(
    model_id="us.anthropic.claude-haiku-4-5-20251001-v1:0",
    region_name='us-west-2',
    temperature=0.3,
)

agent = Agent(model=bedrock_model)

# %% [markdown]
# More details on the available model providers on the [Model Provider Quickstart page](https://strandsagents.com/0.1.x/user-guide/quickstart/#model-providers)

# %% [markdown]
# **Congratulations !! Now you have learned how to build a simple agent using Strands!!**

# %% [markdown]
# ## [Optional] Lets Build a Task-Specific Agent - RecipeBot 🍽️
#
# Lets create a practical example of a task-specific agent. We create a `RecipeBot` that recommends recipes and answers any cooking related questions. Lets dive in !!
#
# Here's what we will create :

# %% [markdown]
# <div style="text-align:center">
#     <img src="images/interactive_recipe_agent.png" width="75%" />
# </div>

# %%
# Install the required packages
# %pip install ddgs # Also install strands-agents strands-agents-tools if you haven't already
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\batto\Src\NLPtoSQL\.venv\Scripts\python.exe: No module named pip

# %%
from strands import Agent, tool
from ddgs import DDGS
from ddgs.exceptions import RatelimitException, DDGSException
import logging

# Configure logging
logging.getLogger("strands").setLevel(logging.INFO)

# Define a websearch tool
@tool
def websearch(keywords: str, region: str = "us-en", max_results: int | None = None) -> str:
    """Search the web to get updated information.
    Args:
        keywords (str): The search query keywords.
        region (str): The search region: wt-wt, us-en, uk-en, ru-ru, etc..
        max_results (int | None): The maximum number of results to return.
    Returns:
        List of dictionaries with search results.
    """
    try:
        results = DDGS().text(keywords, region=region, max_results=max_results)
        return results if results else "No results found."
    except RatelimitException:
        return "RatelimitException: Please try again after a short delay."
    except DDGSException as d:
        return f"DuckDuckGoSearchException: {d}"
    except Exception as e:
        return f"Exception: {e}"

# %%
# Create a recipe assistant agent
recipe_agent = Agent(
    model="us.anthropic.claude-sonnet-4-5-20250929-v1:0",  # Optional: Specify the model ID
    system_prompt="""You are RecipeBot, a helpful cooking assistant.
    Help users find recipes based on ingredients and answer cooking questions.
    Use the websearch tool to find recipes when users mention ingredients or to
    look up cooking information.""",
    # Import the websearch tool we created above
    tools=[websearch],
)

# %%
response = recipe_agent("Suggest a recipe with chicken and broccoli.")

# Other examples:
# response = recipe_agent("How do I cook quinoa?")
# response = recipe_agent("How can I substitute white wine in shrimp pasta?")
# response = recipe_agent("What are the health benefits of asparagus?")
print(response)
# Out:
# Tool #1: websearch
# Based on the search results, I found a great recipe for you! Here's a delicious option:
#
# ## **One Pan Lemon Parmesan Chicken and Broccoli**
#
# This is a healthy and quick recipe that's ready in about 20 minutes!
#
# **What makes it great:**
# - Everything cooks in one pan for easy cleanup
# - Tender lemon chicken with a parmesan coating
# - Crispy roasted broccoli
# - Quick preparation time (under 20 minutes)
#
# **Basic approach:**
# 1. Season chicken pieces with lemon, parmesan, and herbs
# 2. Add broccoli florets to the same pan
# 3. Bake everything together until the chicken is cooked through and the broccoli is crispy
#
# This is a healthy, flavorful meal that combines protein and vegetables in one easy dish!
#
# ---
#
# **Another great option** is a **Chicken and Broccoli Stir-Fry** if you prefer an Asian-style dish. This would involve:
# - Cutting chicken into bite-sized pieces
# - Stir-frying with broccoli florets
# - Adding a savory sauce (typically soy sauce-based)
#
# Would you like more detailed instructions for either of these recipes, or would you prefer a different style of chicken and broccoli dish?Based on the search results, I found a great recipe for you! Here's a delicious option:
#
# ## **One Pan Lemon Parmesan Chicken and Broccoli**
#
# This is a healthy and quick recipe that's ready in about 20 minutes!
#
# **What makes it great:**
# - Everything cooks in one pan for easy cleanup
# - Tender lemon chicken with a parmesan coating
# - Crispy roasted broccoli
# - Quick preparation time (under 20 minutes)
#
# **Basic approach:**
# 1. Season chicken pieces with lemon, parmesan, and herbs
# 2. Add broccoli florets to the same pan
# 3. Bake everything together until the chicken is cooked through and the broccoli is crispy
#
# This is a healthy, flavorful meal that combines protein and vegetables in one easy dish!
#
# ---
#
# **Another great option** is a **Chicken and Broccoli Stir-Fry** if you prefer an Asian-style dish. This would involve:
# - Cutting chicken into bite-sized pieces
# - Stir-frying with broccoli florets
# - Adding a savory sauce (typically soy sauce-based)
#
# Would you like more detailed instructions for either of these recipes, or would you prefer a different style of chicken and broccoli dish?

# %% [markdown]
# #### And that's it! We now have a running usecase agent with tools in just a few lines of code 🥳.
#
# For more detailed quickstart guide, check out the [Strands documentation](https://strandsagents.com/0.1.x/user-guide/quickstart/).

# %% [markdown]
# ### [Optional] Run RecipeBot via CLI:
# you can run the agent in interactive mode via the command line (for instance using the terminal on SageMaker Studio) through the python script provided in `02_simple_interactive_usecase/recipe_bot.py`. This allows you to interact with the agent in a more dynamic way, sending messages and receiving responses via the CLI.
# Run these commands on a command line interface to run the agent in interactive mode:
#
# ```cli
# cd samples/python/01-learn/01-first-agent/02-simple-interactive-usecase/
# pip install -r requirements.txt
# python recipe_bot.py
# ```
#
# With this, you can talk to the bot via a command line interface(CLI).
