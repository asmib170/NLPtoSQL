# %% [markdown]
# # Adding custom tools to your Strands Agents
#
# ## Overview
# In this example we will guide you through the different ways to create custom tools using Strands Agents. We will build a personal assistant use case that connects with a local SQLite database to perform data tasks. As a bonus, we will also guide you through the usage of the reasoning capabilities on Claude Sonnet 4.5 using the `thinking` field of the `BedrockModel` class
#
# ## Agent Details
# <div style="float: left; margin-right: 20px;">
#
# |Feature             |Description                                        |
# |--------------------|---------------------------------------------------|
# |Native tools used   |current_time, calculator                           |
# |Custom tools created|create_appointment, list_appointments              |
# |Agent Structure     |Single agent architecture                          |
#
# </div>

# %% [markdown]
# ## Architecture
#
# <div style="text-align:left">
#     <img src="images/architecture.png" width="85%" />
# </div>
#
# ## Key Features
# * **Single agent architecture**: this example creates a single agent that interacts with built-in and custom tools
# * **Built-in tools**: learn how to use Strands Agent's tools
# * **Custom tools**: lean how to create your own tools
# * **Bedrock Model as underlying LLM**: Used Anthropic Claude Sonnet 4.5 from Amazon Bedrock as the underlying LLM model

# %% [markdown]
# ## Setup and prerequisites
#
# ### Prerequisites
# * Python 3.10+
# * AWS account
# * Anthropic Claude Sonnet 4.5 enabled on Amazon Bedrock, [guide](https://docs.aws.amazon.com/bedrock/latest/userguide/model-access.html)
# * IAM role with permissions to create Amazon Bedrock Knowledge Base, Amazon S3 bucket and Amazon DynamoDB
#
# Let's now install the requirement packages for our Strands Agent

# %%
# installing pre-requisites
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: strands-agents in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 1)) (1.40.0)
# Requirement already satisfied: strands-agents-tools in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from -r requirements.txt (line 2)) (0.5.3)
# Requirement already satisfied: boto3<2.0.0,>=1.26.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents->-r requirements.txt (line 1)) (1.43.12)
# Requirement already satisfied: botocore<2.0.0,>=1.29.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents->-r requirements.txt (line 1)) (1.43.12)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents->-r requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents->-r requirements.txt (line 1)) (4.26.0)
# Requirement already satisfied: mcp<2.0.0,>=1.23.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents->-r requirements.txt (line 1)) (1.27.1)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.30.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents->-r requirements.txt (line 1)) (1.42.1)
# Requirement already satisfied: opentelemetry-instrumentation-threading<1.00b0,>=0.51b0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents->-r requirements.txt (line 1)) (0.63b1)
# Requirement already satisfied: opentelemetry-sdk<2.0.0,>=1.30.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents->-r requirements.txt (line 1)) (1.42.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.4.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents->-r requirements.txt (line 1)) (2.13.4)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.13.2 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents->-r requirements.txt (line 1)) (6.0.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.13.5)
# Requirement already satisfied: aws-requests-auth<0.5.0,>=0.4.3 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.3)
# Requirement already satisfied: dill<0.5.0,>=0.4.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: markdownify<2.0.0,>=1.0.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.2.2)
# Requirement already satisfied: pillow<13.0.0,>=12.1.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (12.2.0)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.51 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (3.0.52)
# Requirement already satisfied: pyjwt<3.0.0,>=2.10.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.12.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: rich<15.0.0,>=14.0.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (14.3.4)
# Requirement already satisfied: slack-bolt<2.0.0,>=1.23.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.28.0)
# Requirement already satisfied: sympy<2.0.0,>=1.12.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: tenacity<10.0.0,>=9.1.2 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (9.1.4)
# Requirement already satisfied: tzdata in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from strands-agents-tools->-r requirements.txt (line 2)) (2025.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (2.6.2)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.0->strands-agents-tools->-r requirements.txt (line 2)) (1.24.2)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: s3transfer<0.18.0,>=0.17.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from boto3<2.0.0,>=1.26.0->strands-agents->-r requirements.txt (line 1)) (0.17.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from botocore<2.0.0,>=1.29.0->strands-agents->-r requirements.txt (line 1)) (2.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jsonschema<5.0.0,>=4.0.0->strands-agents->-r requirements.txt (line 1)) (0.30.0)
# Requirement already satisfied: beautifulsoup4<5,>=4.9 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (4.14.3)
# Requirement already satisfied: six<2,>=1.15 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: anyio>=4.5 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.4.3)
# Requirement already satisfied: httpx<1.0.0,>=0.27.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (2.14.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.0.20)
# Requirement already satisfied: pywin32>=310 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (3.4.4)
# Requirement already satisfied: starlette>=0.27 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.0.0)
# Requirement already satisfied: typing-inspection>=0.4.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.34.0)
# Requirement already satisfied: opentelemetry-instrumentation==0.63b1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.63b1)
# Requirement already satisfied: wrapt<3.0.0,>=1.0.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (2.2.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.63b1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-instrumentation==0.63b1->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (0.63b1)
# Requirement already satisfied: packaging>=18.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opentelemetry-instrumentation==0.63b1->opentelemetry-instrumentation-threading<1.00b0,>=0.51b0->strands-agents->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: wcwidth in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prompt-toolkit<4.0.0,>=3.0.51->strands-agents-tools->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.4.0->strands-agents->-r requirements.txt (line 1)) (2.46.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests<3.0.0,>=2.28.0->strands-agents-tools->-r requirements.txt (line 2)) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.19.1)
# Requirement already satisfied: slack_sdk<4,>=3.38.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from slack-bolt<2.0.0,>=1.23.0->strands-agents-tools->-r requirements.txt (line 2)) (3.42.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy<2.0.0,>=1.12.0->strands-agents-tools->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from anyio>=4.5->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from beautifulsoup4<5,>=4.9->markdownify<2.0.0,>=1.0.0->strands-agents-tools->-r requirements.txt (line 2)) (2.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx<1.0.0,>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.27.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.14.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=14.0.0->strands-agents-tools->-r requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic-settings>=2.5.2->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (48.0.0)
# Requirement already satisfied: click>=7.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from uvicorn>=0.31.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (8.1.8)
# Requirement already satisfied: colorama in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click>=7.0->uvicorn>=0.31.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\batto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.23.0->strands-agents->-r requirements.txt (line 1)) (3.0)
# [notice] A new release of pip is available: 25.0.1 -> 26.1.1
# [notice] To update, run: C:\Users\batto\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Importing dependency packages
#
# Now let's import the dependency packages

# %%
import json
import sqlite3
import uuid
from datetime import datetime

from strands import Agent, tool
from strands.models import BedrockModel

# %% [markdown]
# ## Defining custom tools
# Next let's define custom tools to interact with a local SQLite database:
# * **create_appointment**: create a new personal appointment with unique id, date, location, title and description
# * **list_appointment**: list all available appointments
# * **update_appointments**: update an appointment based on the appointment id

# %% [markdown]
# ### Defining tools in the same file of your agent
#
# There are multiple ways to define tools with the Strands Agents SDK. The first one is to add a `@tool` decorator to your function and provide the documentation to it. In this case, Strands Agents will use the function documentation, typing and arguments to provide the tools to your agent. In this case, you can even define the tool in the same file as your agent

# %%
@tool
def create_appointment(date: str, location: str, title: str, description: str) -> str:
    """
    Create a new personal appointment in the database.

    Args:
        date (str): Date and time of the appointment (format: YYYY-MM-DD HH:MM).
        location (str): Location of the appointment.
        title (str): Title of the appointment.
        description (str): Description of the appointment.

    Returns:
        str: The ID of the newly created appointment.

    Raises:
        ValueError: If the date format is invalid.
    """
    # Validate date format
    try:
        datetime.strptime(date, "%Y-%m-%d %H:%M")
    except ValueError:
        raise ValueError("Date must be in format 'YYYY-MM-DD HH:MM'")

    # Generate a unique ID
    appointment_id = str(uuid.uuid4())

    conn = sqlite3.connect("appointments.db")
    cursor = conn.cursor()

    # Create the appointments table if it doesn't exist
    cursor.execute(
        """
    CREATE TABLE IF NOT EXISTS appointments (
        id TEXT PRIMARY KEY,
        date TEXT,
        location TEXT,
        title TEXT,
        description TEXT
    )
    """
    )

    cursor.execute(
        "INSERT INTO appointments (id, date, location, title, description) VALUES (?, ?, ?, ?, ?)",
        (appointment_id, date, location, title, description),
    )

    conn.commit()
    conn.close()
    return f"Appointment with id {appointment_id} created"

# %% [markdown]
# ### Tool definition with Module-Based Approach
#
# You can also define your tools as a standalone file and import it to your agent. In this case you can still use the decorator approach or you could also define your function using a TOOL_SPEC dictionary. The formating is similar to the one used by the [Amazon Bedrock Converse API](https://docs.aws.amazon.com/bedrock/latest/userguide/tool-use-examples.html) for tool usage. In this case you are more flexible to define the required parameters as well as the return of success and error executions and TOOL_SPEC definitions will work in this case.

# %% [markdown]
# #### Decorator approach
#
# When defining your tool using a decorator in a standalone file, your process is very similar to the one in the same file as your agent, but you will need to import or agent tool later on.

# %%
# %%writefile list_appointments.py
import json
import sqlite3
import os
from strands import tool

@tool
def list_appointments() -> str:
    """
    List all available appointments from the database.
    
    Returns:
        str: the appointments available 
    """
    # Check if database exists
    if not os.path.exists('appointments.db'):
        return "No appointment available"
    
    conn = sqlite3.connect('appointments.db')
    conn.row_factory = sqlite3.Row  # This enables column access by name
    cursor = conn.cursor()
    
    # Check if the appointments table exists
    try:
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name='appointments'")
        if not cursor.fetchone():
            conn.close()
            return "No appointment available"
        
        cursor.execute("SELECT * FROM appointments ORDER BY date")
        rows = cursor.fetchall()
        
        # Convert rows to dictionaries
        appointments = []
        for row in rows:
            appointment = {
                'id': row['id'],
                'date': row['date'],
                'location': row['location'],
                'title': row['title'],
                'description': row['description']
            }
            appointments.append(appointment)
        
        conn.close()
        return json.dumps(appointments)
    
    except sqlite3.Error:
        conn.close()
        return []
# Out:
# Writing list_appointments.py

# %% [markdown]
# #### TOOL_SPEC approach
#
# Alternativelly, you can use the TOOL_SPEC approach when defining your tool

# %%
# %%writefile update_appointment.py
import sqlite3
from datetime import datetime
import os
from strands.types.tools import ToolResult, ToolUse
from typing import Any

TOOL_SPEC = {
    "name": "update_appointment",
    "description": "Update an appointment based on the appointment ID.",
    "inputSchema": {
        "json": {
            "type": "object",
            "properties": {
                "appointment_id": {
                    "type": "string",
                    "description": "The appointment id."
                },
                "date": {
                    "type": "string",
                    "description": "Date and time of the appointment (format: YYYY-MM-DD HH:MM)."
                },
                "location": {
                    "type": "string",
                    "description": "Location of the appointment."
                },
                "title": {
                    "type": "string",
                    "description": "Title of the appointment."
                },
                "description": {
                    "type": "string",
                    "description": "Description of the appointment."
                }
            },
            "required": ["appointment_id"]
        }
    }
}
# Function name must match tool name
def update_appointment(tool: ToolUse, **kwargs: Any) -> ToolResult:
    tool_use_id = tool["toolUseId"]
    appointment_id = tool["input"]["appointment_id"]
    if "date" in tool["input"]:
        date = tool["input"]["date"]
    else:
        date = None
    if "location" in tool["input"]:
        location = tool["input"]["location"]
    else:
        location = None
    if "title" in tool["input"]:
        title = tool["input"]["title"]
    else:
        title = None
    if "description" in tool["input"]:
        description = tool["input"]["description"]
    else:
        description = None
        
    # Check if database exists
    if not os.path.exists('appointments.db'): 
        return {
            "toolUseId": tool_use_id,
            "status": "error",
            "content": [{"text": f"Appointment {appointment_id} does not exist"}]
        } 
    
    # Check if appointment exists
    conn = sqlite3.connect('appointments.db')
    cursor = conn.cursor()
    
    # Check if the appointments table exists
    try:
        cursor.execute("SELECT name FROM sqlite_master WHERE type='table' AND name='appointments'")
        if not cursor.fetchone():
            conn.close()
            return {
                "toolUseId": tool_use_id,
                "status": "error",
                "content": [{"text": f"Appointments table does not exist"}]
            }
        
        cursor.execute("SELECT * FROM appointments WHERE id = ?", (appointment_id,))
        appointment = cursor.fetchone()
        
        if not appointment:
            conn.close()
            return {
                "toolUseId": tool_use_id,
                "status": "error",
                "content": [{"text": f"Appointment {appointment_id} does not exist"}]
            }
        
        # Validate date format if provided
        if date:
            try:
                datetime.strptime(date, '%Y-%m-%d %H:%M')
            except ValueError:
                conn.close()
                return {
                    "toolUseId": tool_use_id,
                    "status": "error",
                    "content": [{"text": "Date must be in format 'YYYY-MM-DD HH:MM'"}]
                }
        
        # Build update query
        update_fields = []
        params = []
        
        if date:
            update_fields.append("date = ?")
            params.append(date)
        
        if location:
            update_fields.append("location = ?")
            params.append(location)
        
        if title:
            update_fields.append("title = ?")
            params.append(title)
        
        if description:
            update_fields.append("description = ?")
            params.append(description)
        
        # If no fields to update
        if not update_fields:
            conn.close()
            return {
                "toolUseId": tool_use_id,
                "status": "success",
                "content": [{"text": "No need to update your appointment, you are all set!"}]
            }
        
        # Complete the query
        query = f"UPDATE appointments SET {', '.join(update_fields)} WHERE id = ?"
        params.append(appointment_id)
        
        cursor.execute(query, params)
        conn.commit()
        conn.close()
        
        return {
            "toolUseId": tool_use_id,
            "status": "success",
            "content": [{"text": f"Appointment {appointment_id} updated with success"}]
        }
    
    except sqlite3.Error as e:
        conn.close()
        return {
            "toolUseId": tool_use_id,
            "status": "error",
            "content": [{"text": str(e)}]
        }
# Out:
# Writing update_appointment.py

# %% [markdown]
# let's now import `list_appointments` and `update_appointment` as a tool

# %%
import list_appointments
import update_appointment

# %% [markdown]
# ## Creating Agent
#
# Now that we have created our custom tools, let's define our first agent. To do so, we need to create a system prompt that defines what the agent should and should not do. We will then define our agent's underlying LLM model and we will provide it with built-in and custom tools.
#
# #### Setting agent system prompt
# In the system prompt we will define the instructions for our agent

# %%
system_prompt = """You are a helpful personal assistant that specializes in managing my appointments and calendar. 
You have access to appointment management tools, a calculator, and can check the current time to help me organize my schedule effectively. 
Always provide the appointment id so that I can update it if required"""

# %% [markdown]
# #### Defining agent underlying LLM model
#
# Next let's define our agent underlying model. Strands Agents natively integrate with Amazon Bedrock models, and provides the ability to configure how the model is called. Below, you can see a simple initialization of a `BedrockModel` provider, with some of the optional configurations commented out. You can learn more about configuration options, and default values, at [Strands Agents Bedrock Model Provider documentation](https://strandsagents.com/0.1.x/user-guide/concepts/model-providers/amazon-bedrock/). For our example, we will use the `Anthropic Claude Sonnet 4.5` model from Bedrock.

# %%
model = BedrockModel(
    model_id="us.anthropic.claude-sonnet-4-5-20250929-v1:0",
    # region_name="us-east-1",
    # boto_client_config=Config(
    #    read_timeout=900,
    #    connect_timeout=900,
    #    retries=dict(max_attempts=3, mode="adaptive"),
    # ),
    # temperature=0.9,
    # max_tokens=2048,
)

# %% [markdown]
# #### Import built-in tools
#
# The next step to build our agent is to import our Strands Agents built-in tools. Strands Agents provides a set of commonly used built-in tools in the optional package `strands-tools`. You have tools for RAG, memory, file operations, code interpretation and others available in this repo. For our example we will use the `current_time` tool to provide our agent with the information about the current time and the `calculator` tool to do some math

# %%
from strands_tools import calculator, current_time

# %% [markdown]
# #### Defining Agent
#
# Now that we have all the required information available, let's define our agent

# %%
agent = Agent(
    model=model,
    system_prompt=system_prompt,
    tools=[
        current_time,
        calculator,
        create_appointment,
        list_appointments,
        update_appointment,
    ],
)

# %% [markdown]
# ## Invoking agent
#
# Let's now invoke our restaurant agent with a greeting and analyse its results

# %%
results = agent("How much is 2+2?")
# Out:
# Tool #1: calculator
# ╭────────────────────────────────────────────── Calculation Result ───────────────────────────────────────────────╮
# │                                                                                                                 │
# │  ╭───────────┬─────────────────────╮                                                                            │
# │  │ Operation │ Evaluate Expression │                                                                            │
# │  │ Input     │ 2+2                 │                                                                            │
# │  │ Result    │ 4                   │                                                                            │
# │  ╰───────────┴─────────────────────╯                                                                            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# The answer is **4**.

# %% [markdown]
# #### Analysing the agent's results
#
# Nice! We've invoked our agent for the first time! Let's now explore the results object. First thing we can see is the messages being exchanged by the agent in the agent's object

# %%
agent.messages
# Out:
# [{'role': 'user', 'content': [{'text': 'How much is 2+2?'}]},
#  {'role': 'assistant',
#   'content': [{'toolUse': {'toolUseId': 'tooluse_PJE9B3RHSKmtQ0VsmYt8xE',
#      'name': 'calculator',
#      'input': {'expression': '2+2'}}}],
#   'metadata': {'usage': {'inputTokens': 2499,
#     'outputTokens': 53,
#     'totalTokens': 2552},
#    'metrics': {'latencyMs': 1809, 'timeToFirstByteMs': 1804}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'status': 'success',
#      'content': [{'text': 'Result: 4'}],
#      'toolUseId': 'tooluse_PJE9B3RHSKmtQ0VsmYt8xE'}}]},
#  {'role': 'assistant',
#   'content': [{'text': 'The answer is **4**.'}],
#   'metadata': {'usage': {'inputTokens': 2569,
#     'outputTokens': 6,
#     'totalTokens': 2575},
#    'metrics': {'latencyMs': 1871, 'timeToFirstByteMs': 1625}}}]

# %% [markdown]
# Next we can take a look at the usage of our agent for the last query by analysing the result `metrics`

# %%
results.metrics
# Out:
# EventLoopMetrics(cycle_count=2, tool_metrics={'calculator': ToolMetrics(tool={'toolUseId': 'tooluse_PJE9B3RHSKmtQ0VsmYt8xE', 'name': 'calculator', 'input': {'expression': '2+2'}}, call_count=1, success_count=1, error_count=0, total_time=0.024381399154663086)}, cycle_durations=[2.1477980613708496, 1.9041996002197266], agent_invocations=[AgentInvocation(cycles=[EventLoopCycleMetric(event_loop_cycle_id='9da66714-acc3-4dec-8b7b-cc81822f3465', usage={'inputTokens': 2499, 'outputTokens': 53, 'totalTokens': 2552}), EventLoopCycleMetric(event_loop_cycle_id='b40a6a90-1336-4e0c-aa62-04489bd8504d', usage={'inputTokens': 2569, 'outputTokens': 6, 'totalTokens': 2575})], usage={'inputTokens': 5068, 'outputTokens': 59, 'totalTokens': 5127})], traces=[<strands.telemetry.metrics.Trace object at 0x0000024A850B4910>, <strands.telemetry.metrics.Trace object at 0x0000024A82F5A8D0>], accumulated_usage={'inputTokens': 5068, 'outputTokens': 59, 'totalTokens': 5127}, accumulated_metrics={'latencyMs': 3680})

# %% [markdown]
# #### Invoking agent with follow up question
# Ok, let's now make an appointment for tomorrow

# %%
results = agent(
    "Book 'Agent fun' for tomorrow 3pm in NYC. This meeting will discuss all the fun things that an agent can do"
)
# Out:
# I'll book that appointment for you. Let me first check what tomorrow's date is, then create the appointment.
# Tool #2: current_time
#
# Tool #3: create_appointment
# Perfect! I've successfully booked your appointment:
#
# **Appointment Details:**
# - **Title:** Agent fun
# - **Date & Time:** Tomorrow, May 27, 2026 at 3:00 PM
# - **Location:** NYC
# - **Description:** This meeting will discuss all the fun things that an agent can do
# - **Appointment ID:** b0cad506-0335-45d3-893f-7b635875c27a
#
# You can use this appointment ID if you need to update the appointment later.

# %% [markdown]
# #### Updating appointment
#
# Let's now update this appointment

# %%
results = agent("Oh no! My bad, 'Agent fun' is actually happening in DC")
# Out:
# No problem! Let me update that appointment for you with the correct location.
# Tool #4: update_appointment
# All fixed! I've updated your appointment:
#
# **Updated Appointment Details:**
# - **Title:** Agent fun
# - **Date & Time:** Tomorrow, May 27, 2026 at 3:00 PM
# - **Location:** DC (updated from NYC)
# - **Description:** This meeting will discuss all the fun things that an agent can do
# - **Appointment ID:** b0cad506-0335-45d3-893f-7b635875c27a
#
# The location has been changed to DC!

# %% [markdown]
# #### Analysing the agent's results
# Let's look at the agent messages and result metrics again

# %%
agent.messages
# Out:
# [{'role': 'user', 'content': [{'text': 'How much is 2+2?'}]},
#  {'role': 'assistant',
#   'content': [{'toolUse': {'toolUseId': 'tooluse_PJE9B3RHSKmtQ0VsmYt8xE',
#      'name': 'calculator',
#      'input': {'expression': '2+2'}}}],
#   'metadata': {'usage': {'inputTokens': 2499,
#     'outputTokens': 53,
#     'totalTokens': 2552},
#    'metrics': {'latencyMs': 1809, 'timeToFirstByteMs': 1804}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'status': 'success',
#      'content': [{'text': 'Result: 4'}],
#      'toolUseId': 'tooluse_PJE9B3RHSKmtQ0VsmYt8xE'}}]},
#  {'role': 'assistant',
#   'content': [{'text': 'The answer is **4**.'}],
#   'metadata': {'usage': {'inputTokens': 2569,
#     'outputTokens': 6,
#     'totalTokens': 2575},
#    'metrics': {'latencyMs': 1871, 'timeToFirstByteMs': 1625}}},
#  {'role': 'user',
#   'content': [{'text': "Book 'Agent fun' for tomorrow 3pm in NYC. This meeting will discuss all the fun things that an agent can do"}]},
#  {'role': 'assistant',
#   'content': [{'text': "I'll book that appointment for you. Let me first check what tomorrow's date is, then create the appointment."},
#    {'toolUse': {'toolUseId': 'tooluse_7DcnqIn6F6GCwjEsepqTDc',
#      'name': 'current_time',
#      'input': {}}}],
#   'metadata': {'usage': {'inputTokens': 2608,
#     'outputTokens': 46,
#     'totalTokens': 2654},
#    'metrics': {'latencyMs': 1741, 'timeToFirstByteMs': 1205}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'toolUseId': 'tooluse_7DcnqIn6F6GCwjEsepqTDc',
#      'status': 'success',
#      'content': [{'text': '2026-05-26T17:19:26.580529+00:00'}]}}]},
#  {'role': 'assistant',
#   'content': [{'toolUse': {'toolUseId': 'tooluse_yQlQsOzs4audAzShjjH4vi',
#      'name': 'create_appointment',
#      'input': {'title': 'Agent fun',
#       'date': '2026-05-27 15:00',
#       'location': 'NYC',
#       'description': 'This meeting will discuss all the fun things that an agent can do'}}}],
#   'metadata': {'usage': {'inputTokens': 2699,
#     'outputTokens': 126,
#     'totalTokens': 2825},
#    'metrics': {'latencyMs': 2927, 'timeToFirstByteMs': 1898}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'toolUseId': 'tooluse_yQlQsOzs4audAzShjjH4vi',
#      'status': 'success',
#      'content': [{'text': 'Appointment with id b0cad506-0335-45d3-893f-7b635875c27a created'}]}}]},
#  {'role': 'assistant',
#   'content': [{'text': "Perfect! I've successfully booked your appointment:\n\n**Appointment Details:**\n- **Title:** Agent fun\n- **Date & Time:** Tomorrow, May 27, 2026 at 3:00 PM\n- **Location:** NYC\n- **Description:** This meeting will discuss all the fun things that an agent can do\n- **Appointment ID:** b0cad506-0335-45d3-893f-7b635875c27a\n\nYou can use this appointment ID if you need to update the appointment later."}],
#   'metadata': {'usage': {'inputTokens': 2865,
#     'outputTokens': 120,
#     'totalTokens': 2985},
#    'metrics': {'latencyMs': 3643, 'timeToFirstByteMs': 2381}}},
#  {'role': 'user',
#   'content': [{'text': "Oh no! My bad, 'Agent fun' is actually happening in DC"}]},
#  {'role': 'assistant',
#   'content': [{'text': 'No problem! Let me update that appointment for you with the correct location.'},
#    {'toolUse': {'toolUseId': 'tooluse_OJSJHC856KZw8iymlm4IJd',
#      'name': 'update_appointment',
#      'input': {'appointment_id': 'b0cad506-0335-45d3-893f-7b635875c27a',
#       'location': 'DC'}}}],
#   'metadata': {'usage': {'inputTokens': 3004,
#     'outputTokens': 110,
#     'totalTokens': 3114},
#    'metrics': {'latencyMs': 2279, 'timeToFirstByteMs': 1215}}},
#  {'role': 'user',
#   'content': [{'toolResult': {'toolUseId': 'tooluse_OJSJHC856KZw8iymlm4IJd',
#      'status': 'success',
#      'content': [{'text': 'Appointment b0cad506-0335-45d3-893f-7b635875c27a updated with success'}]}}]},
#  {'role': 'assistant',
#   'content': [{'text': "All fixed! I've updated your appointment:\n\n**Updated Appointment Details:**\n- **Title:** Agent fun\n- **Date & Time:** Tomorrow, May 27, 2026 at 3:00 PM\n- **Location:** DC (updated from NYC)\n- **Description:** This meeting will discuss all the fun things that an agent can do\n- **Appointment ID:** b0cad506-0335-45d3-893f-7b635875c27a\n\nThe location has been changed to DC!"}],
#   'metadata': {'usage': {'inputTokens': 3154,
#     'outputTokens': 115,
#     'totalTokens': 3269},
#    'metrics': {'latencyMs': 2938, 'timeToFirstByteMs': 1829}}}]

# %%
results.metrics
# Out:
# EventLoopMetrics(cycle_count=7, tool_metrics={'calculator': ToolMetrics(tool={'toolUseId': 'tooluse_PJE9B3RHSKmtQ0VsmYt8xE', 'name': 'calculator', 'input': {'expression': '2+2'}}, call_count=1, success_count=1, error_count=0, total_time=0.024381399154663086), 'current_time': ToolMetrics(tool={'toolUseId': 'tooluse_7DcnqIn6F6GCwjEsepqTDc', 'name': 'current_time', 'input': {}}, call_count=1, success_count=1, error_count=0, total_time=0.0), 'create_appointment': ToolMetrics(tool={'toolUseId': 'tooluse_yQlQsOzs4audAzShjjH4vi', 'name': 'create_appointment', 'input': {'title': 'Agent fun', 'date': '2026-05-27 15:00', 'location': 'NYC', 'description': 'This meeting will discuss all the fun things that an agent can do'}}, call_count=1, success_count=1, error_count=0, total_time=0.023200273513793945), 'update_appointment': ToolMetrics(tool={'toolUseId': 'tooluse_OJSJHC856KZw8iymlm4IJd', 'name': 'update_appointment', 'input': {'appointment_id': 'b0cad506-0335-45d3-893f-7b635875c27a', 'location': 'DC'}}, call_count=1, success_count=1, error_count=0, total_time=0.02703261375427246)}, cycle_durations=[2.1477980613708496, 1.9041996002197266, 1.7718608379364014, 2.9814069271087646, 3.6746227741241455, 2.342857837677002, 2.9772629737854004], agent_invocations=[AgentInvocation(cycles=[EventLoopCycleMetric(event_loop_cycle_id='9da66714-acc3-4dec-8b7b-cc81822f3465', usage={'inputTokens': 2499, 'outputTokens': 53, 'totalTokens': 2552}), EventLoopCycleMetric(event_loop_cycle_id='b40a6a90-1336-4e0c-aa62-04489bd8504d', usage={'inputTokens': 2569, 'outputTokens': 6, 'totalTokens': 2575})], usage={'inputTokens': 5068, 'outputTokens': 59, 'totalTokens': 5127}), AgentInvocation(cycles=[EventLoopCycleMetric(event_loop_cycle_id='8c8cc5f2-9f65-456c-94e3-c04a73bb15ae', usage={'inputTokens': 2608, 'outputTokens': 46, 'totalTokens': 2654}), EventLoopCycleMetric(event_loop_cycle_id='ae89d896-7b74-4746-bfcd-2f10cc54c625', usage={'inputTokens': 2699, 'outputTokens': 126, 'totalTokens': 2825}), EventLoopCycleMetric(event_loop_cycle_id='722aaf43-ac97-4d44-b350-e8c486c1a1b1', usage={'inputTokens': 2865, 'outputTokens': 120, 'totalTokens': 2985})], usage={'inputTokens': 8172, 'outputTokens': 292, 'totalTokens': 8464}), AgentInvocation(cycles=[EventLoopCycleMetric(event_loop_cycle_id='b34e5c13-7b38-4235-9968-20760f025527', usage={'inputTokens': 3004, 'outputTokens': 110, 'totalTokens': 3114}), EventLoopCycleMetric(event_loop_cycle_id='c81ecc6f-23a6-4ddc-9437-483b48791313', usage={'inputTokens': 3154, 'outputTokens': 115, 'totalTokens': 3269})], usage={'inputTokens': 6158, 'outputTokens': 225, 'totalTokens': 6383})], traces=[<strands.telemetry.metrics.Trace object at 0x0000024A850B4910>, <strands.telemetry.metrics.Trace object at 0x0000024A82F5A8D0>, <strands.telemetry.metrics.Trace object at 0x0000024A82B563D0>, <strands.telemetry.metrics.Trace object at 0x0000024A83BBFB90>, <strands.telemetry.metrics.Trace object at 0x0000024A82F5BE90>, <strands.telemetry.metrics.Trace object at 0x0000024A850B7C50>, <strands.telemetry.metrics.Trace object at 0x0000024A835A2450>], accumulated_usage={'inputTokens': 19398, 'outputTokens': 576, 'totalTokens': 19974}, accumulated_metrics={'latencyMs': 17208})

# %% [markdown]
# #### Checking tool usage from messages
#
# Let's deep-dive into the tool usage in the messages dictionary. Later on we will show case how to observe and evaluate your agent's behavior, but this is the first step in this direction

# %%
for m in agent.messages:
    for content in m["content"]:
        if "toolUse" in content:
            print("Tool Use:")
            tool_use = content["toolUse"]
            print("\tToolUseId: ", tool_use["toolUseId"])
            print("\tname: ", tool_use["name"])
            print("\tinput: ", tool_use["input"])
        if "toolResult" in content:
            print("Tool Result:")
            tool_result = m["content"][0]["toolResult"]
            print("\tToolUseId: ", tool_result["toolUseId"])
            print("\tStatus: ", tool_result["status"])
            print("\tContent: ", tool_result["content"])
            print("=======================")
# Out:
# Tool Use:
# 	ToolUseId:  tooluse_PJE9B3RHSKmtQ0VsmYt8xE
# 	name:  calculator
# 	input:  {'expression': '2+2'}
# Tool Result:
# 	ToolUseId:  tooluse_PJE9B3RHSKmtQ0VsmYt8xE
# 	Status:  success
# 	Content:  [{'text': 'Result: 4'}]
# =======================
# Tool Use:
# 	ToolUseId:  tooluse_7DcnqIn6F6GCwjEsepqTDc
# 	name:  current_time
# 	input:  {}
# Tool Result:
# 	ToolUseId:  tooluse_7DcnqIn6F6GCwjEsepqTDc
# 	Status:  success
# 	Content:  [{'text': '2026-05-26T17:19:26.580529+00:00'}]
# =======================
# Tool Use:
# 	ToolUseId:  tooluse_yQlQsOzs4audAzShjjH4vi
# 	name:  create_appointment
# 	input:  {'title': 'Agent fun', 'date': '2026-05-27 15:00', 'location': 'NYC', 'description': 'This meeting will discuss all the fun things that an agent can do'}
# Tool Result:
# 	ToolUseId:  tooluse_yQlQsOzs4audAzShjjH4vi
# 	Status:  success
# 	Content:  [{'text': 'Appointment with id b0cad506-0335-45d3-893f-7b635875c27a created'}]
# =======================
# Tool Use:
# 	ToolUseId:  tooluse_OJSJHC856KZw8iymlm4IJd
# 	name:  update_appointment
# 	input:  {'appointment_id': 'b0cad506-0335-45d3-893f-7b635875c27a', 'location': 'DC'}
# Tool Result:
# 	ToolUseId:  tooluse_OJSJHC856KZw8iymlm4IJd
# 	Status:  success
# 	Content:  [{'text': 'Appointment b0cad506-0335-45d3-893f-7b635875c27a updated with success'}]
# =======================

# %% [markdown]
# ### Validating that the action was performed correctly
# Let's now check our database to confirm that the operations where done correctly. The `Agent` class has the ability for directly calling tools the agent was initialized with by calling `agent.tool.<tool_name>(<tool_params>)`. Direct tool calls are great for giving the agent information from a tool without needing the agent to invoke that tool itself. We can use this direct tool invocation to list the current appointments:

# %%
list_appointments_result = agent.tool.list_appointments()
print(json.dumps(list_appointments_result, indent=2))
# Out:
# {
#   "toolUseId": "tooluse_list_appointments_411408723",
#   "status": "success",
#   "content": [
#     {
#       "text": "[{\"id\": \"b0cad506-0335-45d3-893f-7b635875c27a\", \"date\": \"2026-05-27 15:00\", \"location\": \"DC\", \"title\": \"Agent fun\", \"description\": \"This meeting will discuss all the fun things that an agent can do\"}]"
#     }
#   ]
# }

# %% [markdown]
# We can see that the result of executing the tool is in the ToolResult format, including a `toolUseId`, an execution `status`, and the `content` of the response. We can better visualize the tool's result like this:

# %%
list_appointments_result_text_content = list_appointments_result["content"][0]["text"]
print(json.dumps(json.loads(list_appointments_result_text_content), indent=2))
# Out:
# [
#   {
#     "id": "b0cad506-0335-45d3-893f-7b635875c27a",
#     "date": "2026-05-27 15:00",
#     "location": "DC",
#     "title": "Agent fun",
#     "description": "This meeting will discuss all the fun things that an agent can do"
#   }
# ]

# %% [markdown]
# Finally, when executing tools using direct tool invocation, the agent records these executions in its messages history. By default this is enabled, but can be disabled with the `record_direct_tool_call` boolean flag attribute on the `Agent` class.

# %%
current_time_result = agent.tool.current_time()
print("Current Time direct tool call result:")
print(current_time_result)
current_time_direct_tool_messages = agent.messages[-4:]
print("Current Time direct tool call messages:")
print(current_time_direct_tool_messages)

agent.record_direct_tool_call = False # Set the record_direct_tool_call to False
agent.tool.list_appointments()
after_disable_record_messages = agent.messages[-4:]
print("After disabling record direct tool call messages, history should not have changed:")
print(current_time_direct_tool_messages == after_disable_record_messages)
# Out:
# Current Time direct tool call result:
# {'toolUseId': 'tooluse_current_time_139541843', 'status': 'success', 'content': [{'text': '2026-05-26T17:32:03.171507+00:00'}]}
# Current Time direct tool call messages:
# [{'role': 'user', 'content': [{'text': 'agent.tool.current_time direct tool call.\nInput parameters: {}\n'}]}, {'role': 'assistant', 'content': [{'toolUse': {'toolUseId': 'tooluse_current_time_139541843', 'name': 'current_time', 'input': {}}}]}, {'role': 'user', 'content': [{'toolResult': {'toolUseId': 'tooluse_current_time_139541843', 'status': 'success', 'content': [{'text': '2026-05-26T17:32:03.171507+00:00'}]}}]}, {'role': 'assistant', 'content': [{'text': 'agent.tool.current_time was called.'}]}]
# After disabling record direct tool call messages, history should not have changed:
# True

# %% [markdown]
# ## Extension: Extended Thinking
#
# Extended thinking enables supported Claude-family models the ability to leverage enhanced reasoning capabilities for complex tasks, providing transparent step-by-step thought processes before delivering final answers. To enable thinking, you can include the configuration below when configuring your Bedrock ModelProvider. You can learn more at [AWS's documentation on Extended Thinking](https://docs.aws.amazon.com/bedrock/latest/userguide/claude-messages-extended-thinking.html).

# %%
thinking_model = BedrockModel(
    model_id="us.anthropic.claude-sonnet-4-5-20250929-v1:0",
    additional_request_fields={
        "thinking": {
            "type": "enabled",
            "budget_tokens": 2048,
        }
    },
)

# %% [markdown]
# After defining the `thinking_model`, you can create and invoke a new `thinking_agent`:

# %%
thinking_system_prompt = """You are a helpful personal assistant that specializes in managing my appointments and calendar. 
You have access to appointment management tools, a calculator, and can check the current time to help me organize my schedule effectively. 
You think through your problem, step by step, to come up with an answer.
Always provide the appointment id so that I can update it if required"""

thinking_agent = Agent(
    model=thinking_model,
    system_prompt=thinking_system_prompt,
    tools=[
        current_time,
        calculator,
        create_appointment,
        list_appointments,
        update_appointment,
    ],
)

thinking_result = thinking_agent("I want to add a new appointment for tomorrow at 2pm")
# Out:
# The user wants to add a new appointment for tomorrow at 2pm. To create an appointment, I need:
# - date (format: YYYY-MM-DD HH:MM) - required
# - location - required
# - title - required
# - description - required
#
# The user has only provided the date/time (tomorrow at 2pm), but I'm missing:
# - The title of the appointment
# - The location
# - The description
#
# I should first check what time it is now to determine what "tomorrow" means, but actually I need more information from the user about the title, location, and description before I can create the appointment.
#
# Let me ask the user for these required details.I'd be happy to help you create an appointment for tomorrow at 2pm! However, I need a few more details to complete the appointment:
#
# 1. **Title**: What is the appointment for?
# 2. **Location**: Where will this appointment take place?
# 3. **Description**: Any additional details about the appointment?
#
# Please provide these details so I can create the appointment for you.

# %% [markdown]
# We can better analyze the extended thinking capabilities by printing out the agent's messages. Extended thinking is represented as `reasoningContent` blocks in the response from the agent.

# %%
thinking_agent.messages
# Out:
# [{'role': 'user',
#   'content': [{'text': 'I want to add a new appointment for tomorrow at 2pm'}]},
#  {'role': 'assistant',
#   'content': [{'reasoningContent': {'reasoningText': {'text': 'The user wants to add a new appointment for tomorrow at 2pm. To create an appointment, I need:\n- date (format: YYYY-MM-DD HH:MM) - required\n- location - required\n- title - required\n- description - required\n\nThe user has only provided the date/time (tomorrow at 2pm), but I\'m missing:\n- The title of the appointment\n- The location\n- The description\n\nI should first check what time it is now to determine what "tomorrow" means, but actually I need more information from the user about the title, location, and description before I can create the appointment.\n\nLet me ask the user for these required details.',
#       'signature': '...'}}},
#    {'text': "I'd be happy to help you create an appointment for tomorrow at 2pm! However, I need a few more details to complete the appointment:\n\n1. **Title**: What is the appointment for?\n2. **Location**: Where will this appointment take place?\n3. **Description**: Any additional details about the appointment?\n\nPlease provide these details so I can create the appointment for you."}],
#   'metadata': {'usage': {'inputTokens': 2552,
#     'outputTokens': 240,
#     'totalTokens': 2792},
#    'metrics': {'latencyMs': 5133, 'timeToFirstByteMs': 2061}}}]

# %% [markdown]
# ## Great work !
# See you in the next module. :)
